# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("sap_stock.csv")

# %%
df.head()
df = df.drop(columns='Date')

# %%
df.describe()
# Out:
#               Open         High          Low        Close     Change  \
# count  2648.000000  2981.000000  2981.000000  2988.000000  11.000000
# mean     65.991424    69.757746    68.509819    69.079700  -0.070000
# std      28.013445    28.198972    27.681073    27.983287   0.709761
# min      25.160000    25.820000    24.480000    25.590000  -0.740000
# 25%      43.492500    45.800000    44.760000    44.970000  -0.500000
# 50%      58.735000    61.500000    60.640000    61.000000  -0.290000
# 75%      82.350000    92.240000    90.620000    91.422500   0.085000
# max     142.800000   143.240000   141.080000   142.340000   1.250000
#
#        Traded Volume      Turnover  Last Price of the Day  Daily Traded Units  \
# count   2.942000e+03  2.935000e+03                    0.0                 0.0
# mean    3.158713e+06  1.953571e+08                    NaN                 NaN
# std     2.026167e+06  1.205243e+08                    NaN                 NaN
# min     0.000000e+00  7.936064e+04                    NaN                 NaN
# 25%     2.027710e+06  1.314660e+08                    NaN                 NaN
# 50%     2.711029e+06  1.711970e+08                    NaN                 NaN
# 75%     3.767555e+06  2.263262e+08                    NaN                 NaN
# max     3.645671e+07  1.376505e+09                    NaN                 NaN
#
#        Daily Turnover
# count             7.0
# mean              0.0
# std               0.0
# min               0.0
# 25%               0.0
# 50%               0.0
# 75%               0.0
# max               0.0

# %%
df.cov()
# Out:
#                                Open          High           Low         Close  \
# Open                   7.847531e+02  7.912365e+02  7.762611e+02  7.839226e+02
# High                   7.912365e+02  7.951820e+02  7.802632e+02  7.881006e+02
# Low                    7.762611e+02  7.802632e+02  7.662418e+02  7.736478e+02
# Close                  7.839226e+02  7.881006e+02  7.736478e+02  7.830644e+02
# Change                          NaN -1.667550e+00 -1.712750e+00 -1.521500e+00
# Traded Volume         -2.329656e+07 -2.245362e+07 -2.263350e+07 -2.220861e+07
# Turnover               7.353646e+08  8.563675e+08  7.968788e+08  8.283483e+08
# Last Price of the Day           NaN           NaN           NaN           NaN
# Daily Traded Units              NaN           NaN           NaN           NaN
# Daily Turnover                  NaN           NaN           NaN  0.000000e+00
#
#                              Change  Traded Volume      Turnover  \
# Open                            NaN  -2.329656e+07  7.353646e+08
# High                  -1.667550e+00  -2.245362e+07  8.563675e+08
# Low                   -1.712750e+00  -2.263350e+07  7.968788e+08
# Close                 -1.521500e+00  -2.220861e+07  8.283483e+08
# Change                 5.037600e-01   1.452201e+05  7.357665e+06
# Traded Volume          1.452201e+05   4.105354e+12  1.678042e+14
# Turnover               7.357665e+06   1.678042e+14  1.452611e+16
# Last Price of the Day           NaN            NaN           NaN
# Daily Traded Units              NaN            NaN           NaN
# Daily Turnover                  NaN   0.000000e+00           NaN
#
#                        Last Price of the Day  Daily Traded Units  \
# Open                                     NaN                 NaN
# High                                     NaN                 NaN
# Low                                      NaN                 NaN
# Close                                    NaN                 NaN
# Change                                   NaN                 NaN
# Traded Volume                            NaN                 NaN
# Turnover                                 NaN                 NaN
# Last Price of the Day                    NaN                 NaN
# Daily Traded Units                       NaN                 NaN
# Daily Turnover                           NaN                 NaN
#
#                        Daily Turnover
# Open                              NaN
# High                              NaN
# Low                               NaN
# Close                             0.0
# Change                            NaN
# Traded Volume                     0.0
# Turnover                          NaN
# Last Price of the Day             NaN
# Daily Traded Units                NaN
# Daily Turnover                    0.0

# %%
df.corr()
# Out:
#                            Open      High       Low     Close    Change  \
# Open                   1.000000  0.999776  0.999711  0.999520       NaN
# High                   0.999776  1.000000  0.999597  0.999721 -0.263573
# Low                    0.999711  0.999597  1.000000  0.999748 -0.269992
# Close                  0.999520  0.999721  0.999748  1.000000 -0.241259
# Change                      NaN -0.263573 -0.269992 -0.241259  1.000000
# Traded Volume         -0.399680 -0.392326 -0.402880 -0.390382  0.324919
# Turnover               0.220783  0.251117  0.238052  0.245017  0.177278
# Last Price of the Day       NaN       NaN       NaN       NaN       NaN
# Daily Traded Units          NaN       NaN       NaN       NaN       NaN
# Daily Turnover              NaN       NaN       NaN       NaN       NaN
#
#                        Traded Volume  Turnover  Last Price of the Day  \
# Open                       -0.399680  0.220783                    NaN
# High                       -0.392326  0.251117                    NaN
# Low                        -0.402880  0.238052                    NaN
# Close                      -0.390382  0.245017                    NaN
# Change                      0.324919  0.177278                    NaN
# Traded Volume               1.000000  0.688332                    NaN
# Turnover                    0.688332  1.000000                    NaN
# Last Price of the Day            NaN       NaN                    NaN
# Daily Traded Units               NaN       NaN                    NaN
# Daily Turnover                   NaN       NaN                    NaN
#
#                        Daily Traded Units  Daily Turnover
# Open                                  NaN             NaN
# High                                  NaN             NaN
# Low                                   NaN             NaN
# Close                                 NaN             NaN
# Change                                NaN             NaN
# Traded Volume                         NaN             NaN
# Turnover                              NaN             NaN
# Last Price of the Day                 NaN             NaN
# Daily Traded Units                    NaN             NaN
# Daily Turnover                        NaN             NaN

# %%
df.skew()
# Out:
# Open                     0.817303
# High                     0.529694
# Low                      0.519637
# Close                    0.525958
# Change                   1.289171
# Traded Volume            4.179990
# Turnover                 3.350085
# Last Price of the Day         NaN
# Daily Traded Units            NaN
# Daily Turnover           0.000000
# dtype: float64

# %%
df.kurt()
# Out:
# Open                     -0.185576
# High                     -0.635641
# Low                      -0.648205
# Close                    -0.642641
# Change                    0.593512
# Traded Volume            44.634988
# Turnover                 20.006294
# Last Price of the Day          NaN
# Daily Traded Units             NaN
# Daily Turnover            0.000000
# dtype: float64

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Open', y='Close')
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
fig, ax = plt.subplots(figsize=(11, 9))
sb.heatmap(df)
plt.show()
